# %%
import pandas as pd

def show_dataframe(filename):  ######## This function takes filename as argument and returns the contents as dataframe
    df = pd.read_csv(filename)
    df_t = df.T
    return df
show_dataframe(r"climate change.csv")
# Out:
#       Country Name Country Code  \
# 0            Aruba          ABW
# 1            Aruba          ABW
# 2            Aruba          ABW
# 3            Aruba          ABW
# 4            Aruba          ABW
# ...            ...          ...
# 20211     Zimbabwe          ZWE
# 20212     Zimbabwe          ZWE
# 20213     Zimbabwe          ZWE
# 20214     Zimbabwe          ZWE
# 20215     Zimbabwe          ZWE
#
#                                           Indicator Name     Indicator Code  \
# 0               Urban population (% of total population)  SP.URB.TOTL.IN.ZS
# 1                                       Urban population        SP.URB.TOTL
# 2                     Urban population growth (annual %)        SP.URB.GROW
# 3                                      Population, total        SP.POP.TOTL
# 4                           Population growth (annual %)        SP.POP.GROW
# ...                                                  ...                ...
# ...

# %%
df.info() #### Dataframe information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20216 entries, 0 to 20215
# Data columns (total 65 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    20216 non-null  object
#  1   Country Code    20216 non-null  object
#  2   Indicator Name  20216 non-null  object
#  3   Indicator Code  20216 non-null  object
#  4   1960            3140 non-null   float64
#  5   1961            4546 non-null   float64
#  6   1962            4727 non-null   float64
#  7   1963            4587 non-null   float64
#  8   1964            4643 non-null   float64
#  9   1965            4679 non-null   float64
#  10  1966            4690 non-null   float64
#  11  1967            4859 non-null   float64
#  12  1968            4711 non-null   float64
#  13  1969            4718 non-null   float64
#  14  1970            5987 non-null   float64
#  15  1971            7338 non-null   float64
#  16  1972            7545 non-null   float64
# ...

# %%
df['Indicator Name'].value_counts()  ##### Returns the counts of all the Indicator names corresponding to each country.
# Out:
# Urban population (% of total population)                                                      266
# CO2 intensity (kg per kg of oil equivalent energy use)                                        266
# Renewable electricity output (% of total electricity output)                                  266
# Electricity production from renewable sources, excluding hydroelectric (kWh)                  266
# Electricity production from renewable sources, excluding hydroelectric (% of total)           266
#                                                                                              ...
# GHG net emissions/removals by LUCF (Mt of CO2 equivalent)                                     266
# Droughts, floods, extreme temperatures (% of population, average 1990-2009)                   266
# Rural population living in areas where elevation is below 5 meters (% of total population)    266
# Urban population living in areas where elevation is below 5 meters (% of total population)    266
# ...

# %%
df['Country Name'].value_counts()   #### Returns count of each country. The counts correspond to number of indicator names
# Out:
# Aruba                   76
# Oman                    76
# Malawi                  76
# Malaysia                76
# North America           76
#                         ..
# Guyana                  76
# High income             76
# Hong Kong SAR, China    76
# Honduras                76
# Zimbabwe                76
# Name: Country Name, Length: 266, dtype: int64

# %%
######## This cell contains code for analysis of the indicator urban population
######## We clean the dataset by dropping all the nan values. For exploring the data analysis we take 6 countries.
######## Correlation between each country is computed and a heatmap is plotted for visual understanding of the data
######## Also statistical analysis is done on the data which includes calculating mean, standard deviation, min, max and others
######## Also for each country data over the years 1961-2020 is plotted.

df_urban_population = df.loc[df['Indicator Name'] == 'Urban population (% of total population)']
df_urban_population = df_urban_population.drop(columns=['Country Code', 'Indicator Name', 'Indicator Code','1960'])
df_urban_population = df_urban_population.dropna(how='any')
df_urban_population = df_urban_population.reset_index(drop=True)
df_urban_population_t = df_urban_population.set_index('Country Name').T
urban_x = df_urban_population_t[['United Arab Emirates','South Africa','Vietnam','India','Argentina','China']].describe()
print(urban_x)
df_urban_population_t = df_urban_population_t[['United Arab Emirates','South Africa','Vietnam','India','Argentina','China']]
corrurban = df_urban_population_t.corr()
print(corrurban)
sns.heatmap(corrurban,cmap="YlGnBu", annot=True)
df_urban_population_t.plot()
# Out:
# Country Name  United Arab Emirates  South Africa    Vietnam      India  \
# count                    60.000000     60.000000  60.000000  60.000000
# mean                     80.799933     54.166433  23.216883  25.672667
# std                       2.849289      6.638610   6.180319   4.841417
# min                      74.383000     46.793000  15.031000  18.032000
# 25%                      79.253000     48.154000  18.855500  21.590750
# 50%                      79.856500     52.295500  20.443000  25.662500
# 75%                      82.358500     59.671250  27.432750  29.318500
# max                      87.048000     67.354000  37.340000  34.926000
#
# Country Name  Argentina      China
# count         60.000000  60.000000
# mean          85.476667  31.557600
# std            5.358693  14.431987
# min           74.217000  16.708000
# 25%           81.266750  17.911250
# 50%           87.156000  26.877000
# 75%           90.073250  42.858500
# max           92.111000  61.428000
# ...

# %%
######## This cell contains code for analysis of the indicator population growth
######## We clean the dataset by dropping all the nan values. For exploring the data analysis we take 6 countries.
######## Correlation between each country is computed and a heatmap is plotted for visual understanding of the data
######## Also statistical analysis is done on the data which includes calculating mean, standard deviation, min, max and others
######## Also for each country data over the years 1961-2020 is plotted.

df_population_growth = df.loc[df['Indicator Name'] == 'Population growth (annual %)']
df_population_growth = df_population_growth.drop(columns=['Country Code', 'Indicator Name', 'Indicator Code','1960'])
df_population_growth = df_population_growth.reset_index(drop=True)
df_population_growth = df_population_growth.set_index('Country Name').T
population_growth=df_population_growth[['United Arab Emirates','South Africa','Vietnam','India','Argentina','China']].describe()
print(population_growth)
df_population_growth=df_population_growth[['United Arab Emirates','South Africa','Vietnam','India','Argentina','China']]
corrpopgrowth = df_population_growth.corr()
print(corrpopgrowth)
sns.heatmap(corrpopgrowth,cmap="YlGnBu", annot=True)
df_population_growth.plot()
# Out:
# Country Name  United Arab Emirates  South Africa    Vietnam      India  \
# count                    60.000000     60.000000  60.000000  60.000000
# mean                      7.788348      2.072812   1.819561   1.865630
# std                       4.750593      0.565058   0.712804   0.426172
# min                       0.176775      1.217762   0.904518   0.989414
# 25%                       5.194996      1.467771   1.035447   1.571206
# 50%                       5.930010      2.379592   2.121555   2.017542
# 75%                      10.924275      2.566418   2.299195   2.230198
# max                      17.633410      2.758618   3.003303   2.331906
#
# Country Name  Argentina      China
# count         60.000000  60.000000
# mean           1.325774   1.248515
# std            0.246662   0.786929
# min            0.752218  -1.015528
# 25%            1.089914   0.618457
# 50%            1.427210   1.187578
# 75%            1.554179   1.561405
# max            1.624717   2.787332
# ...

# %%
######## This cell contains code for analysis of the indicator CO2 emissions
######## We clean the dataset by dropping all the nan values. For exploring the data analysis we take 6 countries.
######## Correlation between each country is computed and a heatmap is plotted for visual understanding of the data
######## Also statistical analysis is done on the data which includes calculating mean, standard deviation, min, max and others
######## Also for each country data over the years 1961-2020 is plotted.

df_co2 = df.loc[df['Indicator Name'] == 'CO2 emissions (kt)']
df_co2 = df_co2.drop(columns=['Country Code', 'Indicator Name', 'Indicator Code','1960'])
df_co2 = df_co2.reset_index(drop=True)
df_co2 = df_co2.set_index('Country Name').T
co_x=df_co2[['United Arab Emirates','South Africa','Vietnam','India','Argentina','China']].describe()
print(co_x)
df_co2=df_co2[['United Arab Emirates','South Africa','Vietnam','India','Argentina','China']]
corrco = df_co2.corr()
print(corrco)
sns.heatmap(corrco,cmap="YlGnBu", annot=True)
df_co2.plot()
# Out:
# Country Name  United Arab Emirates   South Africa        Vietnam  \
# count                     58.00000      58.000000      58.000000
# mean                   74698.01450  278276.103552   57349.242293
# std                    61471.20383  105615.319129   64669.206234
# min                       11.00100  102213.958000    6164.227000
# 25%                    32331.02225  187180.181500   17520.009250
# 50%                    54943.97650  279609.593500   24389.281500
# 75%                   108367.50000  371507.500000   80960.000000
# max                   208250.00000  447980.000000  257860.000000
#
# Country Name         India      Argentina         China
# count         5.800000e+01      58.000000  5.800000e+01
# mean          7.855542e+05  117460.879810  3.515656e+06
# std           6.603591e+05   37936.984539  3.187986e+06
# min           1.304022e+05   50083.886000  4.332340e+05
# 25%           2.550976e+05   96623.616500  1.158254e+06
# ...

# %%
######## This cell contains code for analysis of the indicator arable land
######## We clean the dataset by dropping all the nan values. For exploring the data analysis we take 6 countries.
######## Correlation between each country is computed and a heatmap is plotted for visual understanding of the data
######## Also statistical analysis is done on the data which includes calculating mean, standard deviation, min, max and others
######## Also for each country data over the years 1961-2020 is plotted.

df_arable = df.loc[df['Indicator Name'] == 'Arable land (% of land area)']
df_arable = df_arable.drop(columns=['Country Code', 'Indicator Name', 'Indicator Code','1960'])
df_arable = df_arable.reset_index(drop=True)
df_arable = df_arable.set_index('Country Name').T
arable_x=df_arable[['United Arab Emirates','South Africa','Vietnam','India','Argentina','China']].describe()
print(arable_x)
df_arable=df_arable[['United Arab Emirates','South Africa','Vietnam','India','Argentina','China']]
corrable = df_arable.corr()
print(corrable)
sns.heatmap(corrable,cmap="YlGnBu", annot=True)
df_arable.plot()
# Out:
# Country Name  United Arab Emirates  South Africa    Vietnam      India  \
# count                    58.000000     58.000000  58.000000  58.000000
# mean                      0.431496     10.430317  18.579840  53.904595
# std                       0.282293      0.464591   1.878615   0.840948
# min                       0.070403      9.892094  16.402962  52.403647
# 25%                       0.154886     10.106422  17.054287  53.142164
# 50%                       0.450577     10.328995  17.793173  53.981078
# 75%                       0.626584     10.613392  20.441836  54.714297
# max                       1.056041     11.385800  22.584578  55.031128
#
# Country Name  Argentina      China
# count         58.000000  58.000000
# mean          10.441465  11.958757
# std            2.089111   1.095429
# min            6.795435  10.286715
# 25%            9.500528  10.783977
# 50%            9.865568  12.696478
# 75%           11.054275  12.838008
# max           14.526307  13.320891
# ...

# %%
######## This cell contains code for analysis of the indicator agricultural land
######## We clean the dataset by dropping all the nan values. For exploring the data analysis we take 6 countries.
######## Correlation between each country is computed and a heatmap is plotted for visual understanding of the data
######## Also statistical analysis is done on the data which includes calculating mean, standard deviation, min, max and others
######## Also for each country data over the years 1961-2020 is plotted.

df_agri = df.loc[df['Indicator Name'] == 'Agricultural land (% of land area)']
df_agri = df_agri.drop(columns=['Country Code', 'Indicator Name', 'Indicator Code','1960'])
df_agri = df_agri.reset_index(drop=True)
df_agri = df_agri.set_index('Country Name').T
agri_x = df_agri[['United Arab Emirates','South Africa','Vietnam','India','Argentina','China']].describe()
print(agri_x)
df_agri = df_agri[['United Arab Emirates','South Africa','Vietnam','India','Argentina','China']]
corragri = df_agri.corr()
print(corragri)
sns.heatmap(corragri,cmap="YlGnBu", annot=True)
df_agri.plot()
# Out:
# Country Name  United Arab Emirates  South Africa    Vietnam      India  \
# count                    58.000000     58.000000  58.000000  58.000000
# mean                      4.585704     79.378509  25.168637  60.456713
# std                       1.748070      1.321451   6.617454   0.510112
# min                       2.928752     77.515271  19.330855  58.843195
# 25%                       3.030836     78.248522  20.158837  60.398932
# 50%                       3.689102     79.417850  21.177302  60.536663
# 75%                       5.458674     80.314321  31.383075  60.852905
# max                       7.969586     83.534610  39.256297  61.074469
#
# Country Name  Argentina      China
# count         58.000000  58.000000
# mean          48.772668  49.548769
# std            2.850196   7.211373
# min           46.545279  36.420045
# 25%           46.869302  42.771814
# 50%           47.078405  53.422560
# 75%           50.227328  55.804949
# max           54.538146  56.133200
# ...

# %%
######## This cell contains code for analysis of the indicator electric power consumption
######## We clean the dataset by dropping all the nan values. For exploring the data analysis we take 6 countries.
######## Correlation between each country is computed and a heatmap is plotted for visual understanding of the data
######## Also statistical analysis is done on the data which includes calculating mean, standard deviation, min, max and others
######## Also for each country data over the years 1961-2020 is plotted.

df_electric_power = df.loc[df['Indicator Name'] == 'Electric power consumption (kWh per capita)']
df_electric_power = df_electric_power.drop(columns=['Country Code', 'Indicator Name', 'Indicator Code','1960'])
df_electric_power = df_electric_power.reset_index(drop=True)
df_electric_power = df_electric_power.set_index('Country Name').T
electric_power = df_electric_power[['United Arab Emirates','South Africa','Vietnam','India','Argentina','China']].describe()
print(electric_power)
df_electric_power = df_electric_power[['United Arab Emirates','South Africa','Vietnam','India','Argentina','China']]
corrM = df_electric_power.corr()
print(corrM)
sns.heatmap(corrM,cmap="YlGnBu", annot=True)
df_electric_power.plot()
# Out:
# Country Name  United Arab Emirates  South Africa      Vietnam       India  \
# count                    44.000000     44.000000    44.000000   44.000000
# mean                   8343.000729   3991.581354   323.339875  335.182516
# std                    3436.767302    715.115395   391.867286  198.598853
# min                     681.171904   2239.903218    33.887597   97.772718
# 25%                    6867.478376   3732.390190    55.627606  156.544698
# 50%                    8799.999848   4201.873923   106.951781  312.491288
# 75%                   11124.343515   4546.890616   445.889072  435.765259
# max                   12502.698510   4851.692494  1423.699910  804.516349
#
# Country Name    Argentina        China
# count           44.000000    44.000000
# mean          1746.760133  1080.455213
# std            668.979653  1081.839830
# min            874.459244   151.989347
# 25%           1237.016574   295.852885
# 50%           1474.605405   633.665364
# ...

# %%
### This cell calculates the correlation of all 6 countries between CO2 emissions and Urban Population

df_co2.corrwith(df_urban_population_t, axis = 0)
# Out:
# Country Name
# United Arab Emirates    0.894707
# South Africa            0.889791
# Vietnam                 0.959252
# India                   0.939932
# Argentina               0.923054
# China                   0.977544
# dtype: float64

# %%
### This cell calculates the correlation of all 6 countries between agricultural land and Arable land

df_agri.corrwith(df_arable, axis = 0)
# Out:
# Country Name
# United Arab Emirates    0.930443
# South Africa            0.311428
# Vietnam                 0.946707
# India                   0.617098
# Argentina               0.807328
# China                   0.897800
# dtype: float64

# %%
### This cell calculates the correlation of all 6 countries between Urban Population and Electric power consumption

df_urban_population_t.corrwith(df_electric_power, axis = 0)
# Out:
# Country Name
# United Arab Emirates    0.384677
# South Africa            0.734409
# Vietnam                 0.967532
# India                   0.971183
# Argentina               0.897583
# China                   0.947133
# dtype: float64
